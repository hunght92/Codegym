# %%
# THAO TÁC VỚI DỮ LIỆU: LỌC DỮ LIỆU, GOM NHÓM DỮ LIỆU, SINH DỮ LIỆU TỪ CÁC CỘT ĐÃ CÓ

# %%
# LỌC DỮ LIỆU: Có 4 phương pháp: Lọc trực tiếp bởi chỉ số dòng và tên cột, Lọc bằng phương thức filter, lọc có điều kiện, lọc có điều kiện bằng phương thức query

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("shopeep_koreantop_clothing_shop_data.csv", header = 0, encoding = "UTF8")
data
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pk_shop             746 non-null    int64
#  1   date_collected      746 non-null    object
#  2   shopid              746 non-null    int64
#  3   name                746 non-null    object
#  4   join_month          746 non-null    object
#  5   join_day            746 non-null    int64
#  6   join_year           746 non-null    int64
#  7   item_count          746 non-null    int64
#  8   follower_count      746 non-null    int64
#  9   response_time       746 non-null    object
#  10  response_rate       746 non-null    int64
#  11  shop_location       428 non-null    object
#  12  rating_bad          746 non-null    int64
#  13  rating_good         746 non-null    int64
#  14  rating_normal       746 non-null    int64
#  15  rating_star         740 non-null    float64
# ...

# %%
# Lọc dữ liệu sử dụng .loc và .iloc

# %%
# Lọc lấy cột name
data.loc[:, "name"]
# Out:
# 0              hello.may.ph
# 1           love.women.shop
# 2             R&O RedOrange
# 3               patriciacai
# 4      Little Market Manila
#                ...
# 741       Yacent_thrift_Clo
# 742             Akistore.ph
# 743            Yzanice Shop
# 744          Clairecvc Shop
# 745             angelcity.💋
# Name: name, Length: 746, dtype: object

# %%
# Lọc lấy cột name và shop location
data.loc[:, ["name","shop_location"]]
# Out:
#                      name               shop_location
# 0            hello.may.ph                         NaN
# 1         love.women.shop    San Nicolas,Metro Manila
# 2           R&O RedOrange     Pasay City,Metro Manila
# 3             patriciacai        Binondo,Metro Manila
# 4    Little Market Manila  Caloocan City,Metro Manila
# ..                    ...                         ...
# 741     Yacent_thrift_Clo          Legazpi City,Albay
# 742           Akistore.ph                         NaN
# 743          Yzanice Shop                         NaN
# 744        Clairecvc Shop        Binondo,Metro Manila
# 745           angelcity.💋     Pasay City,Metro Manila
#
# [746 rows x 2 columns]

# %%
# Lọc lấy cột name tới shop location
data.loc[:, "name":"shop_location"]
# Out:
#                      name join_month  join_day  join_year  item_count  \
# 0            hello.may.ph      April        27       2020         446
# 1         love.women.shop  September        25       2020         263
# 2           R&O RedOrange  September        27       2016         209
# 3             patriciacai      April        30       2017         165
# 4    Little Market Manila    October        18       2016         467
# ..                    ...        ...       ...        ...         ...
# 741     Yacent_thrift_Clo        May        22       2021          16
# 742           Akistore.ph      March         3       2021          84
# 743          Yzanice Shop   December        20       2020          78
# 744        Clairecvc Shop     August         2       2017         964
# 745           angelcity.💋       June        17       2017         272
#
#      follower_count response_time  response_rate               shop_location
# ...

# %%
# Lọc lấy hàng có index = 222
data.loc[222]
# Out:
# pk_shop               20210621417317962
# date_collected               2021-06-21
# shopid                        417317962
# name                         MEIMEITALL
# join_month                        April
# join_day                              5
# join_year                          2021
# item_count                          477
# follower_count                     1430
# response_time                  09:20:04
# response_rate                        96
# shop_location                       NaN
# rating_bad                            7
# rating_good                         471
# rating_normal                        19
# rating_star                        4.82
# is_shopee_verified                    1
# is_official_shop                      0
# Name: 222, dtype: object

# %%
# Lọc lấy hàng có index = 222, 444, 666
data.loc[[222, 444, 666],:]
# Out:
#                pk_shop date_collected     shopid        name join_month  \
# 222  20210621417317962     2021-06-21  417317962  MEIMEITALL      April
# 444  20210628401079546     2021-06-28  401079546     Huidong      March
# 666   2021070647114599     2021-07-06   47114599  Simplediva   December
#
#      join_day  join_year  item_count  follower_count response_time  \
# 222         5       2021         477            1430      09:20:04
# 444        11       2021          22             533      09:02:00
# 666         9       2017          79           34690      09:52:02
#
#      response_rate                 shop_location  rating_bad  rating_good  \
# 222             96                           NaN           7          471
# 444             91         Sampaloc,Metro Manila           0          177
# 666             91  Valenzuela City,Metro Manila         797        64748
#
#      rating_normal  rating_star  is_shopee_verified  is_official_shop
# ...

# %%
# Lọc lấy hàng có index từ 100 đến 200
data.loc[100:200,:]
# Out:
#                pk_shop date_collected     shopid                       name  \
# 100   2021061339587061     2021-06-13   39587061       wolfzone online shop
# 101  20210613315447242     2021-06-13  315447242                   liwen.ph
# 102  20210613266644184     2021-06-13  266644184              JUNEtime Shop
# 103  20210613302250255     2021-06-13  302250255           Zero Tide Hanbok
# 104   2021061351801232     2021-06-13   51801232                     DriFIT
# ..                 ...            ...        ...                        ...
# 196  20210621299396535     2021-06-21  299396535  Pretty Comy Women Fashion
# 197   2021062112280641     2021-06-21   12280641               R Squared PH
# 198   2021062125587666     2021-06-21   25587666             Kily.Ph Online
# 199   2021062136365595     2021-06-21   36365595         korean terno dress
# 200  20210621276895504     2021-06-21  276895504                     MC.com
#
# ...

# %%
# Lọc lấy bảng có index từ 300 đến 400 chỉ chứa cột từ "rating_bad" đến "rating_star"
data.loc[300:400,"rating_bad":"rating_star"]
# Out:
#      rating_bad  rating_good  rating_normal  rating_star
# 300           8          449             31         4.72
# 301         130         3831            319         4.63
# 302        2415        69278           4317         4.67
# 303          98         1586            139         4.53
# 304        5123       659093          14751         4.88
# ..          ...          ...            ...          ...
# 396          96         3588            241         4.70
# 397          27         8131            154         4.91
# 398          11          701             29         4.82
# 399          29          890             74         4.65
# 400        3332        75478           6467         4.58
#
# [101 rows x 4 columns]

# %%
data.iloc[300:401,12:16]
# Out:
#      rating_bad  rating_good  rating_normal  rating_star
# 300           8          449             31         4.72
# 301         130         3831            319         4.63
# 302        2415        69278           4317         4.67
# 303          98         1586            139         4.53
# 304        5123       659093          14751         4.88
# ..          ...          ...            ...          ...
# 396          96         3588            241         4.70
# 397          27         8131            154         4.91
# 398          11          701             29         4.82
# 399          29          890             74         4.65
# 400        3332        75478           6467         4.58
#
# [101 rows x 4 columns]

# %%
# Lọc bằng hàm filter, 
# Lọc cột: df.filter([Tên cột], axis = 1, mặc định)
# Lọc hàng: df.filter(chỉ số dòng, axis = 0) # Phải chọn axis = 0
# Lọc dữ liệu theo cột và dòng: df.filter([Tên cột 1, ..., Tên cột n])[chỉ số dòng đầu: chỉ số dòng cuối + 1]

# %%
# Lọc lấy cột name
data.filter(["name"]) #[741:] #bản chất là lấy tất cả các dòng
# Out:
#                      name
# 0            hello.may.ph
# 1         love.women.shop
# 2           R&O RedOrange
# 3             patriciacai
# 4    Little Market Manila
# ..                    ...
# 741     Yacent_thrift_Clo
# 742           Akistore.ph
# 743          Yzanice Shop
# 744        Clairecvc Shop
# 745           angelcity.💋
#
# [746 rows x 1 columns]

# %%
# Lọc lấy cột name và shop location
data.filter(["name","shop_location"])[:]
# Out:
#                      name               shop_location
# 0            hello.may.ph                         NaN
# 1         love.women.shop    San Nicolas,Metro Manila
# 2           R&O RedOrange     Pasay City,Metro Manila
# 3             patriciacai        Binondo,Metro Manila
# 4    Little Market Manila  Caloocan City,Metro Manila
# ..                    ...                         ...
# 741     Yacent_thrift_Clo          Legazpi City,Albay
# 742           Akistore.ph                         NaN
# 743          Yzanice Shop                         NaN
# 744        Clairecvc Shop        Binondo,Metro Manila
# 745           angelcity.💋     Pasay City,Metro Manila
#
# [746 rows x 2 columns]

# %%
# lọc lấy cột name đến shop location
data.filter(["name":"shop_location"]) #Filter không sử dụng được slicer nên phải gõ thủ công
# Out:
#   Input In [18]
#     data.filter(["name":"shop_location"]) #Filter không sử dụng được slicer nên phải gõ thủ công
#                        ^
# SyntaxError: invalid syntax

# %%
# Lọc lấy hàng có index = 222
data.filter([222], axis = 0)
# Out:
#                pk_shop date_collected     shopid        name join_month  \
# 222  20210621417317962     2021-06-21  417317962  MEIMEITALL      April
#
#      join_day  join_year  item_count  follower_count response_time  \
# 222         5       2021         477            1430      09:20:04
#
#      response_rate shop_location  rating_bad  rating_good  rating_normal  \
# 222             96           NaN           7          471             19
#
#      rating_star  is_shopee_verified  is_official_shop
# 222         4.82                   1                 0

# %%
# Lọc lấy hàng có index = 222, 444, 666
data.filter([222, 444, 666], axis = 0)
# Out:
#                pk_shop date_collected     shopid        name join_month  \
# 222  20210621417317962     2021-06-21  417317962  MEIMEITALL      April
# 444  20210628401079546     2021-06-28  401079546     Huidong      March
# 666   2021070647114599     2021-07-06   47114599  Simplediva   December
#
#      join_day  join_year  item_count  follower_count response_time  \
# 222         5       2021         477            1430      09:20:04
# 444        11       2021          22             533      09:02:00
# 666         9       2017          79           34690      09:52:02
#
#      response_rate                 shop_location  rating_bad  rating_good  \
# 222             96                           NaN           7          471
# 444             91         Sampaloc,Metro Manila           0          177
# 666             91  Valenzuela City,Metro Manila         797        64748
#
#      rating_normal  rating_star  is_shopee_verified  is_official_shop
# ...

# %%
# lọc lấy hàng có index từ 100 tới 200
# data.filter([Các tên cột])[100:201]

# %%
# Lọc lấy bảng có index từ 300 đến 400 chỉ chứa cột từ "rating_bad" đến "rating_star"
data.filter(["rating_bad", "rating_good", "rating_normal", "rating_star"])[300:401]
# Out:
#      rating_bad  rating_good  rating_normal  rating_star
# 300           8          449             31         4.72
# 301         130         3831            319         4.63
# 302        2415        69278           4317         4.67
# 303          98         1586            139         4.53
# 304        5123       659093          14751         4.88
# ..          ...          ...            ...          ...
# 396          96         3588            241         4.70
# 397          27         8131            154         4.91
# 398          11          701             29         4.82
# 399          29          890             74         4.65
# 400        3332        75478           6467         4.58
#
# [101 rows x 4 columns]

# %%
# LỌC SỬ DỤNG ĐIỀU KIỆN

# %%
# Lọc theo điều kiện đơn
# df[df["tên cột"] Phương thức so sánh Giá trị]
# Trong đó phép toán so sánh PTSS sử dụng các phép toán so sánh gồm ==, <, <=, >, >=, !=
# Giá trị cần so sánh được để trong cặp dấu nháy đơn nếu có kiểu chuỗi ký tự

# %%
# Lọc lấy dữ liệu có tháng tham gia là tháng 6
data[data["join_month"] == "June"] # Chained indexing
# Out:
#                pk_shop date_collected     shopid                        name  \
# 31   20210613277581138     2021-06-13  277581138      John see way's shop.ph
# 40   20210613276428558     2021-06-13  276428558            cottonandbuttons
# 46   20210613275875058     2021-06-13  275875058            small__tomato.ph
# 61   20210613274192652     2021-06-13  274192652               Kate's Corner
# 66    2021061374965889     2021-06-13   74965889                 its.la.mode
# 67   20210613273590933     2021-06-13  273590933               Korean. House
# 68   20210613271800741     2021-06-13  271800741                1989minishop
# 99   20210613273569988     2021-06-13  273569988                      sy1688
# 105  20210613156756973     2021-06-13  156756973                huiluotuo.ph
# 123  20210613276895504     2021-06-13  276895504                      MC.com
# 134    202106136381125     2021-06-13    6381125                   somura.ph
# ...

# %%
data[data.loc[:, "join_month"] == "June"]
# Out:
#                pk_shop date_collected     shopid                        name  \
# 31   20210613277581138     2021-06-13  277581138      John see way's shop.ph
# 40   20210613276428558     2021-06-13  276428558            cottonandbuttons
# 46   20210613275875058     2021-06-13  275875058            small__tomato.ph
# 61   20210613274192652     2021-06-13  274192652               Kate's Corner
# 66    2021061374965889     2021-06-13   74965889                 its.la.mode
# 67   20210613273590933     2021-06-13  273590933               Korean. House
# 68   20210613271800741     2021-06-13  271800741                1989minishop
# 99   20210613273569988     2021-06-13  273569988                      sy1688
# 105  20210613156756973     2021-06-13  156756973                huiluotuo.ph
# 123  20210613276895504     2021-06-13  276895504                      MC.com
# 134    202106136381125     2021-06-13    6381125                   somura.ph
# ...

# %%
# Lọc lấy các shop có trên 500 đánh giá tốt
data[data["rating_good"] >= 500]
# Out:
#                pk_shop date_collected     shopid                   name  \
# 0    20210613254711738     2021-06-13  254711738           hello.may.ph
# 1    20210613314198143     2021-06-13  314198143        love.women.shop
# 2     2021061310377223     2021-06-13   10377223          R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329            patriciacai
# 4     2021061311187885     2021-06-13   11187885   Little Market Manila
# ..                 ...            ...        ...                    ...
# 738  20210706419954100     2021-07-06  419954100  Fall in love with you
# 739   2021070664360491     2021-07-06   64360491              Yzkzks.ph
# 740   2021070616590993     2021-07-06   16590993            Adol Janet
# 744   2021070629392066     2021-07-06   29392066         Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092            angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
# lọc lấy tên và địa chỉ các shop có trên 1000 đánh giá tốt
data[data["rating_good"] >= 1000][["name","shop_location"]]
# Out:
#                       name               shop_location
# 0             hello.may.ph                         NaN
# 1          love.women.shop    San Nicolas,Metro Manila
# 2            R&O RedOrange     Pasay City,Metro Manila
# 3              patriciacai        Binondo,Metro Manila
# 4     Little Market Manila  Caloocan City,Metro Manila
# ..                     ...                         ...
# 738  Fall in love with you                         NaN
# 739              Yzkzks.ph     Pasay City,Metro Manila
# 740            Adol Janet         Binondo,Metro Manila
# 744         Clairecvc Shop        Binondo,Metro Manila
# 745            angelcity.💋     Pasay City,Metro Manila
#
# [531 rows x 2 columns]

# %%
data[data["rating_good"] >= 1000].loc[:,["name","shop_location"]]
# Out:
#                       name               shop_location
# 0             hello.may.ph                         NaN
# 1          love.women.shop    San Nicolas,Metro Manila
# 2            R&O RedOrange     Pasay City,Metro Manila
# 3              patriciacai        Binondo,Metro Manila
# 4     Little Market Manila  Caloocan City,Metro Manila
# ..                     ...                         ...
# 738  Fall in love with you                         NaN
# 739              Yzkzks.ph     Pasay City,Metro Manila
# 740            Adol Janet         Binondo,Metro Manila
# 744         Clairecvc Shop        Binondo,Metro Manila
# 745            angelcity.💋     Pasay City,Metro Manila
#
# [531 rows x 2 columns]

# %%
data[data["rating_good"] >= 1000].filter(["name","shop_location"])
# Out:
#                       name               shop_location
# 0             hello.may.ph                         NaN
# 1          love.women.shop    San Nicolas,Metro Manila
# 2            R&O RedOrange     Pasay City,Metro Manila
# 3              patriciacai        Binondo,Metro Manila
# 4     Little Market Manila  Caloocan City,Metro Manila
# ..                     ...                         ...
# 738  Fall in love with you                         NaN
# 739              Yzkzks.ph     Pasay City,Metro Manila
# 740            Adol Janet         Binondo,Metro Manila
# 744         Clairecvc Shop        Binondo,Metro Manila
# 745            angelcity.💋     Pasay City,Metro Manila
#
# [531 rows x 2 columns]

# %%
data[["name", "shop_location"]][data["rating_good"]>1000]
# Out:
#                       name               shop_location
# 0             hello.may.ph                         NaN
# 1          love.women.shop    San Nicolas,Metro Manila
# 2            R&O RedOrange     Pasay City,Metro Manila
# 3              patriciacai        Binondo,Metro Manila
# 4     Little Market Manila  Caloocan City,Metro Manila
# ..                     ...                         ...
# 738  Fall in love with you                         NaN
# 739              Yzkzks.ph     Pasay City,Metro Manila
# 740            Adol Janet         Binondo,Metro Manila
# 744         Clairecvc Shop        Binondo,Metro Manila
# 745            angelcity.💋     Pasay City,Metro Manila
#
# [531 rows x 2 columns]

# %%
data.loc[:,["name", "shop_location"]][data["rating_good"]>1000]
# Out:
#                       name               shop_location
# 0             hello.may.ph                         NaN
# 1          love.women.shop    San Nicolas,Metro Manila
# 2            R&O RedOrange     Pasay City,Metro Manila
# 3              patriciacai        Binondo,Metro Manila
# 4     Little Market Manila  Caloocan City,Metro Manila
# ..                     ...                         ...
# 738  Fall in love with you                         NaN
# 739              Yzkzks.ph     Pasay City,Metro Manila
# 740            Adol Janet         Binondo,Metro Manila
# 744         Clairecvc Shop        Binondo,Metro Manila
# 745            angelcity.💋     Pasay City,Metro Manila
#
# [531 rows x 2 columns]

# %%
# LỌC THEO ĐIỀU KIỆN PHỨC

# %%
# df[(df["Tên cột 1"] PTSS Giá trị 1) PTLG (df["Tên cột n"] PTSS Giá trị n))
# df[(So sánh 1) PTLG (so sánh 2)] Các điều kiện được nối với nhau bởi phép toán logic PTLG gồm & (và), | (hoặc), ~ (phủ định)

# %%
data
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
# Lọc lấy tên các shop và địa chỉ có trên 1000 đánh giá tốt và trung bình đánh giá trên 4 sao
data[(data["rating_good"] > 1000) & (data["rating_star"] > 4)][["name","shop_location"]]
# Out:
#                       name               shop_location
# 0             hello.may.ph                         NaN
# 1          love.women.shop    San Nicolas,Metro Manila
# 2            R&O RedOrange     Pasay City,Metro Manila
# 3              patriciacai        Binondo,Metro Manila
# 4     Little Market Manila  Caloocan City,Metro Manila
# ..                     ...                         ...
# 738  Fall in love with you                         NaN
# 739              Yzkzks.ph     Pasay City,Metro Manila
# 740            Adol Janet         Binondo,Metro Manila
# 744         Clairecvc Shop        Binondo,Metro Manila
# 745            angelcity.💋     Pasay City,Metro Manila
#
# [531 rows x 2 columns]

# %%
data[(data["rating_good"] > 1000) & (data["rating_star"] > 4)].loc[:, ["name","shop_location"]]
# Out:
#                       name               shop_location
# 0             hello.may.ph                         NaN
# 1          love.women.shop    San Nicolas,Metro Manila
# 2            R&O RedOrange     Pasay City,Metro Manila
# 3              patriciacai        Binondo,Metro Manila
# 4     Little Market Manila  Caloocan City,Metro Manila
# ..                     ...                         ...
# 738  Fall in love with you                         NaN
# 739              Yzkzks.ph     Pasay City,Metro Manila
# 740            Adol Janet         Binondo,Metro Manila
# 744         Clairecvc Shop        Binondo,Metro Manila
# 745            angelcity.💋     Pasay City,Metro Manila
#
# [531 rows x 2 columns]

# %%
data[["name", "shop_location"]]\
[(data["rating_good"] > 1000) &(data["rating_star"] > 4.8)]
# Out:
#                             name              shop_location
# 0                   hello.may.ph                        NaN
# 2                  R&O RedOrange    Pasay City,Metro Manila
# 3                    patriciacai       Binondo,Metro Manila
# 6        Yihua Women's Wear Hall                        NaN
# 12                  peterang.999  Tondo I / Ii,Metro Manila
# ..                           ...                        ...
# 731  loveflower--Fashion women's                        NaN
# 735            🌿 Peppermint Shop                        NaN
# 736                Be Young Life                        NaN
# 739                    Yzkzks.ph    Pasay City,Metro Manila
# 740                  Adol Janet        Binondo,Metro Manila
#
# [249 rows x 2 columns]

# %%
data.loc[:,["name", "shop_location"]]\
[(data["rating_good"] > 1000) &(data["rating_star"] > 4.8)]
# Out:
#                             name              shop_location
# 0                   hello.may.ph                        NaN
# 2                  R&O RedOrange    Pasay City,Metro Manila
# 3                    patriciacai       Binondo,Metro Manila
# 6        Yihua Women's Wear Hall                        NaN
# 12                  peterang.999  Tondo I / Ii,Metro Manila
# ..                           ...                        ...
# 731  loveflower--Fashion women's                        NaN
# 735            🌿 Peppermint Shop                        NaN
# 736                Be Young Life                        NaN
# 739                    Yzkzks.ph    Pasay City,Metro Manila
# 740                  Adol Janet        Binondo,Metro Manila
#
# [249 rows x 2 columns]

# %%
data
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
# Lọc lấy dữ liệu của các shop có trên 5 năm tồn tại, được shopee verify và không có quá 200 đánh giá xấu
data[(data["is_shopee_verified"] == 1) 
     & (data["rating_bad"] < 200) 
     & (2023 - (data["join_year"]) > 5)]
# Out:
#               pk_shop date_collected    shopid         name join_month  \
# 3    2021061321407329     2021-06-13  21407329  patriciacai      April
# 54   2021061329808441     2021-06-13  29808441  ELfille 2.0     August
# 178  2021062121407329     2021-06-21  21407329  patriciacai      April
# 516  2021062821407329     2021-06-28  21407329  patriciacai      April
#
#      join_day  join_year  item_count  follower_count response_time  \
# 3          30       2017         165           18787      09:10:38
# 54          6       2017         128           21450      10:40:10
# 178        30       2017         165           18860      09:18:37
# 516        30       2017         165           18967      09:14:17
#
#      response_rate               shop_location  rating_bad  rating_good  \
# 3               94        Binondo,Metro Manila          44        18959
# 54              88  Marikina City,Metro Manila          15         4915
# ...

# %%
# Lọc lấy các dữ liệu của các shop có địa chỉ ở Manila
# xxx.str.contains("String")==True
data[data["shop_location"].str.contains("Manila")==True]
# Out:
#                pk_shop date_collected     shopid                         name  \
# 1    20210613314198143     2021-06-13  314198143              love.women.shop
# 2     2021061310377223     2021-06-13   10377223                R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329                  patriciacai
# 4     2021061311187885     2021-06-13   11187885         Little Market Manila
# 8    20210613312874722     2021-06-13  312874722     Shopping Center boutique
# ..                 ...            ...        ...                          ...
# 734   2021070650114777     2021-07-06   50114777  BCUA Lingerie Bra and Panty
# 739   2021070664360491     2021-07-06   64360491                    Yzkzks.ph
# 740   2021070616590993     2021-07-06   16590993                  Adol Janet
# 744   2021070629392066     2021-07-06   29392066               Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092                  angelcity.💋
#
# ...

# %%
# Lọc bằng hàm query
# Phương thức truy vấn query giúp câu lệnh truy vấn chạy nhanh hơn
# Các điều kiện được nối với nhau bằng các phép toán logic như and (và), or (hoặc), not (phủ định) và được để trong một cặp dấu nháy kép
# df.query("(Tên cột 1 PTSS Giá trị 1) PTLG (Tên cột n PTSS Giá trị n)")
# df.query("(So sánh 1) PTLG (So sánh 2)")

# %%
# Lọc lấy tên các shop và địa chỉ có trên 100 đánh giá tốt và trung bình đánh giá trên 4.8 sao
data.query("(rating_good > 1000) and (rating_star > 4.8)")\
.loc[:,["name", "shop_location"]]
# Out:
#                             name              shop_location
# 0                   hello.may.ph                        NaN
# 2                  R&O RedOrange    Pasay City,Metro Manila
# 3                    patriciacai       Binondo,Metro Manila
# 6        Yihua Women's Wear Hall                        NaN
# 12                  peterang.999  Tondo I / Ii,Metro Manila
# ..                           ...                        ...
# 731  loveflower--Fashion women's                        NaN
# 735            🌿 Peppermint Shop                        NaN
# 736                Be Young Life                        NaN
# 739                    Yzkzks.ph    Pasay City,Metro Manila
# 740                  Adol Janet        Binondo,Metro Manila
#
# [249 rows x 2 columns]

# %%
# Lọc lấy dữ liệu các shop có từ 5 năm tồn tại, được verify và không có quá 200 đánh giá xấu
data.query("((2023 - join_year) > 5) and (is_shopee_verified == 1) and (rating_bad <200)") # có thể không có () vẫn hoạt động được
# Out:
#               pk_shop date_collected    shopid         name join_month  \
# 3    2021061321407329     2021-06-13  21407329  patriciacai      April
# 54   2021061329808441     2021-06-13  29808441  ELfille 2.0     August
# 178  2021062121407329     2021-06-21  21407329  patriciacai      April
# 516  2021062821407329     2021-06-28  21407329  patriciacai      April
#
#      join_day  join_year  item_count  follower_count response_time  \
# 3          30       2017         165           18787      09:10:38
# 54          6       2017         128           21450      10:40:10
# 178        30       2017         165           18860      09:18:37
# 516        30       2017         165           18967      09:14:17
#
#      response_rate               shop_location  rating_bad  rating_good  \
# 3               94        Binondo,Metro Manila          44        18959
# 54              88  Marikina City,Metro Manila          15         4915
# ...

# %%
# Lọc lấy dữ liệu của các shop có địa chỉ ở Manila
# xxx.str.contains('String')==True
data.query("`shop location`.str.contains('Manila')==True") # phải dùng 'string'
# Out:
#                pk_shop date_collected     shopid                         name  \
# 1    20210613314198143     2021-06-13  314198143              love.women.shop
# 2     2021061310377223     2021-06-13   10377223                R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329                  patriciacai
# 4     2021061311187885     2021-06-13   11187885         Little Market Manila
# 8    20210613312874722     2021-06-13  312874722     Shopping Center boutique
# ..                 ...            ...        ...                          ...
# 734   2021070650114777     2021-07-06   50114777  BCUA Lingerie Bra and Panty
# 739   2021070664360491     2021-07-06   64360491                    Yzkzks.ph
# 740   2021070616590993     2021-07-06   16590993                  Adol Janet
# 744   2021070629392066     2021-07-06   29392066               Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092                  angelcity.💋
#
# ...

# %%
# Nếu trong tên cột có ký tự đặc biệt (space, *, #), phải sử dụng dấu ` (huyền) để ghi tên cột
data.rename(columns = {"shop_location":"shop location"}, inplace = True)
data
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
data.query("`shop location`.str.contains('Manila')==True")
# Out:
#                pk_shop date_collected     shopid                         name  \
# 1    20210613314198143     2021-06-13  314198143              love.women.shop
# 2     2021061310377223     2021-06-13   10377223                R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329                  patriciacai
# 4     2021061311187885     2021-06-13   11187885         Little Market Manila
# 8    20210613312874722     2021-06-13  312874722     Shopping Center boutique
# ..                 ...            ...        ...                          ...
# 734   2021070650114777     2021-07-06   50114777  BCUA Lingerie Bra and Panty
# 739   2021070664360491     2021-07-06   64360491                    Yzkzks.ph
# 740   2021070616590993     2021-07-06   16590993                  Adol Janet
# 744   2021070629392066     2021-07-06   29392066               Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092                  angelcity.💋
#
# ...
