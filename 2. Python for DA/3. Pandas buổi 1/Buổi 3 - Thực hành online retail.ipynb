# %%
import pandas as pd
import numpy as np

# %%
# %pwd
# Out:
# 'C:\\Users\\Hung\\Desktop\\Học\\Codegym\\Codegym\\2. Python for DA\\3. Pandas buổi 1'

# %%
data = pd.read_csv("OnlineRetail.csv", header = 0, encoding = "ISO-8859-1")
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# Tìm ra số hàng và số cột của dữ liệu, xuất ra dưới dạng "Số hàng là xxx, số cột là yyy"
print(f"Số hàng là {data.shape[0]}, số cột là {data.shape[1]}")
# Out:
# Số hàng là 541909, số cột là 8

# %%
# Việt hóa tên cột có dấu
data.columns = ["Số hóa đơn", "Mã hàng hóa", "Tên hàng hóa", "Số lượng", "Ngày hóa đơn", "Đơn giá", "Mã khách hàng", "Xuất xứ"]
data
# Out:
#        Số hóa đơn Mã hàng hóa                         Tên hàng hóa  Số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
# Thêm cột "Thành tiền" vào sau cuối, giá trị mặc định là 0
data["Thành tiền"] = 0
data
# Out:
#        Số hóa đơn Mã hàng hóa                         Tên hàng hóa  Số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
# Thêm cột "Chiết khấu" sa u cột đơn giá, giá trị của cột chiết khấu là 3 (đơn vị là %)
data.insert(6,"Chiết khấu (%)",3)
data
# Out:
#        Số hóa đơn Mã hàng hóa                         Tên hàng hóa  Số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
# Thêm 1 sản phẩm sau hàng thứ 541905, thông tin sản phẩm như sau: 324345, 34534B, Noi chien khong dau, 1000, 23/6/2022 20:30, 50.2, 3, 312313.0, Vietnam, NaN
data.loc[541905.5] = ["324345", "34534B", "Noi chien khong dau", 1000, "23/6/2022 20:30", 50.2, 3, 312313.0, "Vietnam", 0]
data = data.sort_index().reset_index(drop = True)
data
# Out:
#        Số hóa đơn Mã hàng hóa                         Tên hàng hóa  Số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541907     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541908     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541909     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
# 541910     324345      34534B                  Noi chien khong dau      1000
# 541911     324345      34534B                  Noi chien khong dau      1000
#
# ...

# %%
# Tính tiền rồi nhập giá trị Thanh tien = Số lượng x (đơn giá x (100-chiết khấu%))/100
# data.loc[:, "Thành tiền"] = data.loc[:, "Số lượng"] * data.loc[:, "Đơn giá"] * (100 - data.loc)
